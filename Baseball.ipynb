# %% [markdown]
# ## GA Data Science Final Project
# #### An analysis of the predictive value of spring training statisitics on regular season outcomes.

# %% [markdown]
# ###The Question
# ####Are Spring Training Statistics predictive of regular season results?
#
# Every year in North America, the month of April carries within it the inaugoration of a new season of Major League Baseball. But before the first pitch is thrown and the 162 game season gets underway, a whole other season is played as a warm-up known as Spring Training.
#
# Spring Traing runs from mid February to late March and consists of between 15 and 20 games across 2 separate legues based in the American Southwest (Cactus League) and the Southeast (Grapefuit League). The 2 spring leagues are comprised of a mix of teams from both the regular season National and American league divisions. What every one would like to think is that how individual players and teams perform in

# %% [markdown]
# ###The Data
# Logistic regression -- probabilities of binomial events.
#
# fit a Generalized Linear Model to the binomial response to try to predict whether a team makes it to the regular season play-offs.
#
# For this project I will focus solely on hitting statistics and game outcomes. Pitching and fielding stats will not be included. To extend this further we could also account for only stats of players with regular season experience as many teams give young players a chance to prove themselves during spring training.
#
# Features:
# The following is batting data, aggregated by team and is for Spring Training games unless noted
#
# * Year - Year
# * Team - Team Name
# * League - NL (National League) / AL (American League)
# * G - Games played
# * W - Wins
# * WPct - Winning Percentage
# * RegWP - Winning Percentage (Regular Season)
# * RegPS - Qualify for post season (1=yes, 0=no)
# * AB - At bats
# * R - Runs Scored
# * H - Hits
# * x2B - Doubles
# * x3B - Triples
# * HR - Home Runs
# * RBI - Runs Batted In
# * BB - Base on Balls
# * SO - Strike Outs
# * SB - Stolen BAses
# * CS - Cought Stealing
# * AVG - Batting Average
# * OBP - On Base Percentage (The number of times each batter reaches base by hit, walk or hit by pitch, divided by plate appearances including at-bats, walks, hit by pitch and sacrifice flies)
# * SLG - Slugging Percentage (total bases divided by at bats)
# * OPS - On-base percentage plus slugging

# %% [markdown]
# ###Analysis
# First I'll import the necessary libraries.

# %%
#load data
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import feature_selection, linear_model
# Out:
# //anaconda/lib/python2.7/site-packages/pytz/__init__.py:35: UserWarning: Module argparse was already imported from //anaconda/python.app/Contents/lib/python2.7/argparse.pyc, but /anaconda/lib/python2.7/site-packages is being added to sys.path
#   from pkg_resources import resource_stream

# %% [markdown]
# Response variable = RegPS #did they make the play offs? (1=YES, 0=NO)
# Input variables = WPct, R, H, RBI, AVG, OBP, SLG, OPS
# Group By = League

# %%
baseball = pd.read_csv("./baseball.csv")
baseball
# Out:
# //anaconda/lib/python2.7/site-packages/pandas/core/config.py:570: DeprecationWarning: height has been deprecated.
#
#   warnings.warn(d.msg, DeprecationWarning)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 240 entries, 0 to 239
# Data columns (total 23 columns):
# Year      240  non-null values
# Team      240  non-null values
# League    240  non-null values
# G         240  non-null values
# W         240  non-null values
# WPct      240  non-null values
# RegWP     240  non-null values
# RegPS     240  non-null values
# AB        240  non-null values
# R         240  non-null values
# H         240  non-null values
# x2B       240  non-null values
# x3B       240  non-null values
# HR        240  non-null values
# RBI       240  non-null values
# BB        240  non-null values
# SO        240  non-null values
# SB        240  non-null values
# CS        240  non-null values
# AVG       240  non-null values
# OBP       240  non-null values
# SLG       240  non-null values
# ...

# %%
baseball.shape
# Out:
# (240, 23)

# %%
bb = baseball.drop(['G', 'W', 'AB', 'BB', 'SO', 'SB', 'CS'], axis=1)
bb.describe() #bb.mean()   bb.sum()
# Out:
# //anaconda/lib/python2.7/site-packages/pandas/core/config.py:570: DeprecationWarning: height has been deprecated.
#
#   warnings.warn(d.msg, DeprecationWarning)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 240 entries, 0 to 239
# Data columns (total 16 columns):
# Year      240  non-null values
# Team      240  non-null values
# League    240  non-null values
# WPct      240  non-null values
# RegWP     240  non-null values
# RegPS     240  non-null values
# R         240  non-null values
# H         240  non-null values
# x2B       240  non-null values
# x3B       240  non-null values
# HR        240  non-null values
# RBI       240  non-null values
# AVG       240  non-null values
# OBP       240  non-null values
# SLG       240  non-null values
# OPS       240  non-null values
# dtypes: float64(6), int64(8), object(2)

# %%
bb.corr()
# Out:
# //anaconda/lib/python2.7/site-packages/pandas/core/config.py:570: DeprecationWarning: height has been deprecated.
#
#   warnings.warn(d.msg, DeprecationWarning)
# //anaconda/lib/python2.7/site-packages/pandas/core/config.py:570: DeprecationWarning: height has been deprecated.
#
#   warnings.warn(d.msg, DeprecationWarning)
# //anaconda/lib/python2.7/site-packages/pandas/core/config.py:570: DeprecationWarning: height has been deprecated.
#
#   warnings.warn(d.msg, DeprecationWarning)
#            Year      WPct     RegWP     RegPS         R         H       x2B  \
# Year   1.000000 -0.007397  0.000446  0.048426 -0.014651  0.061348 -0.022961
# WPct  -0.007397  1.000000  0.232588  0.145309  0.382557  0.240953  0.269285
# RegWP  0.000446  0.232588  1.000000  0.712087  0.048491  0.031069 -0.015139
# RegPS  0.048426  0.145309  0.712087  1.000000  0.007374 -0.033902 -0.048967
# R     -0.014651  0.382557  0.048491  0.007374  1.000000  0.862000  0.690592
# ...

# %%
bb = bbData['WPct', 'RegWP', 'RegPS', 'R', 'H', 'x2B', 'x3B', 'HR', 'RBI', 'AVG', 'OBP', 'SLG', 'OPS']

#response variables
#playoff = bb['RegPS']
#wp = bb['RegWP']

#input variables
#features = bb['WPct', 'R', 'H', 'x2B', 'x3B', 'HR', 'RBI', 'AVG', 'OBP', 'SLG', 'OPS']

# %% [markdown]
# I'll first want to look at winning percentage (wp) as my response and see...

# %%
#quick analysis of features
features_set = feature_selection.univariate_selection.f_regression(features, wp)

# %%
# !ls ../Michael/
# Out:
# GolafsharProject.ipynb baseball.csv           readme.md
